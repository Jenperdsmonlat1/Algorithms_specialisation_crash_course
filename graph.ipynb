# %%
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 2.9 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 3.4 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.1
#     Uninstalling numpy-2.3.1:
#       Successfully uninstalled numpy-2.3.1
# ...

# %%
# Out:
# Exception ignored on calling ctypes callback function: <function ThreadpoolController._find_libraries_with_dl_iterate_phdr.<locals>.match_library_callback at 0x7f9f67320040>
# Traceback (most recent call last):
#   File "/home/rayane/Desktop/standford_algorithm_specialization/Algorithms_specialisation_crash_course/lib/python3.11/site-packages/threadpoolctl.py", line 1005, in match_library_callback
#     self._make_controller_from_path(filepath)
#   File "/home/rayane/Desktop/standford_algorithm_specialization/Algorithms_specialisation_crash_course/lib/python3.11/site-packages/threadpoolctl.py", line 1187, in _make_controller_from_path
#     lib_controller = controller_class(
#                      ^^^^^^^^^^^^^^^^^
#   File "/home/rayane/Desktop/standford_algorithm_specialization/Algorithms_specialisation_crash_course/lib/python3.11/site-packages/threadpoolctl.py", line 114, in __init__
#     self.dynlib = ctypes.CDLL(filepath, mode=_RTLD_NOLOAD)
# ...

# %%
for node_id, data in graph.nodes(data=True):
    print(node_id, data['x'])
# Out:
# 143403 4.8775406
# 143408 4.8763392
# 143412 4.8628174
# 143413 4.8648442
# 143415 4.8638746
# 143416 4.8648175
# 143417 4.8653524
# 143418 4.8662118
# 143421 4.8683205
# 143435 4.862994
# 143439 4.8537112
# 195222 4.836902
# 195228 4.8296142
# 195231 4.8337706
# 195232 4.8339066
# 195234 4.8386402
# 195235 4.8401349
# 195236 4.8411203
# 195237 4.8428234
# 195239 4.8451082
# 195241 4.8488579
# 195242 4.849161
# 195244 4.8499842
# 195246 4.8518925
# 195249 4.8521067
# 195250 4.8481937
# 195251 4.8466255
# 195252 4.8440857
# 195256 4.8336422
# 195259 4.8599184
# 195261 4.861588
# 195262 4.8604722
# 195266 4.8644645
# 195268 4.8650444
# 195270 4.8653924
# 195271 4.8685939
# 195274 4.8681255
# 195275 4.8676335
# 195276 4.8652133
# 195277 4.8681383
# 195279 4.8704734
# 195282 4.8408271
# 581678 4.8436512
# 7300862 4.8732228
# 7300867 4.8728497
# 7393914 4.7843656
# 7393915 4.7864605
# 7394428 4.7855161
# 7394439 4.7853145
# 7394456 4.7836769
# 7394477 4.7833614
# 7394819 4.7928393
# ...
